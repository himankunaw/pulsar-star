# %% [markdown]
# The dataset for this project can be found on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/HTRU2).

# %%
# Import important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('HTRU_2.CSV')

# %%
df.head()
# Out:
#       Mean_IP      SD_IP     EK_IP  Skewness_IP  Mean_DM_SNR  SD_DM_SNR  \
# 0  140.562500  55.683782 -0.234571    -0.699648     3.199833  19.110426
# 1  102.507812  58.882430  0.465318    -0.515088     1.677258  14.860146
# 2  103.015625  39.341649  0.323328     1.051164     3.121237  21.744669
# 3  136.750000  57.178449 -0.068415    -0.636238     3.642977  20.959280
# 4   88.726562  40.672225  0.600866     1.123492     1.178930  11.468720
#
#    EK_DM_SNR  Skewness_DM_SNR  Class
# 0   7.975532        74.242225      0
# 1  10.576487       127.393580      0
# 2   7.735822        63.171909      0
# 3   6.896499        53.593661      0
# 4  14.269573       252.567306      0

# %%
df
# Out:
#           Mean_IP      SD_IP     EK_IP  Skewness_IP  Mean_DM_SNR  SD_DM_SNR  \
# 0      140.562500  55.683782 -0.234571    -0.699648     3.199833  19.110426
# 1      102.507812  58.882430  0.465318    -0.515088     1.677258  14.860146
# 2      103.015625  39.341649  0.323328     1.051164     3.121237  21.744669
# 3      136.750000  57.178449 -0.068415    -0.636238     3.642977  20.959280
# 4       88.726562  40.672225  0.600866     1.123492     1.178930  11.468720
# ...           ...        ...       ...          ...          ...        ...
# 17893  136.429688  59.847421 -0.187846    -0.738123     1.296823  12.166062
# 17894  122.554688  49.485605  0.127978     0.323061    16.409699  44.626893
# 17895  119.335938  59.935939  0.159363    -0.743025    21.430602  58.872000
# 17896  114.507812  53.902400  0.201161    -0.024789     1.946488  13.381731
# 17897   57.062500  85.797340  1.406391     0.089520   188.306020  64.712562
#
#        EK_DM_SNR  Skewness_DM_SNR  Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17898 entries, 0 to 17897
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Mean_IP          17898 non-null  float64
#  1   SD_IP            17898 non-null  float64
#  2   EK_IP            17898 non-null  float64
#  3   Skewness_IP      17898 non-null  float64
#  4   Mean_DM_SNR      17898 non-null  float64
#  5   SD_DM_SNR        17898 non-null  float64
#  6   EK_DM_SNR        17898 non-null  float64
#  7   Skewness_DM_SNR  17898 non-null  float64
#  8   Class            17898 non-null  int64
# dtypes: float64(8), int64(1)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#             Mean_IP         SD_IP         EK_IP   Skewness_IP   Mean_DM_SNR  \
# count  17898.000000  17898.000000  17898.000000  17898.000000  17898.000000
# mean     111.079968     46.549532      0.477857      1.770279     12.614400
# std       25.652935      6.843189      1.064040      6.167913     29.472897
# min        5.812500     24.772042     -1.876011     -1.791886      0.213211
# 25%      100.929688     42.376018      0.027098     -0.188572      1.923077
# 50%      115.078125     46.947479      0.223240      0.198710      2.801839
# 75%      127.085938     51.023202      0.473325      0.927783      5.464256
# max      192.617188     98.778911      8.069522     68.101622    223.392140
#
#           SD_DM_SNR     EK_DM_SNR  Skewness_DM_SNR         Class
# count  17898.000000  17898.000000     17898.000000  17898.000000
# mean      26.326515      8.303556       104.857709      0.091574
# std       19.470572      4.506092       106.514540      0.288432
# ...

# %%
tab = pd.DataFrame(index = df.columns)
tab['data_type'] = df.dtypes
tab['null_count'] = df.isnull().sum()
tab['unique_count'] = df.nunique()
tab
# Out:
#                 data_type  null_count  unique_count
# Mean_IP           float64           0          8626
# SD_IP             float64           0         17862
# EK_IP             float64           0         17897
# Skewness_IP       float64           0         17898
# Mean_DM_SNR       float64           0          9000
# SD_DM_SNR         float64           0         17894
# EK_DM_SNR         float64           0         17895
# Skewness_DM_SNR   float64           0         17895
# Class               int64           0             2

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (17898, 9)

# %%
df.corr()
# Out:
#                   Mean_IP     SD_IP     EK_IP  Skewness_IP  Mean_DM_SNR  \
# Mean_IP          1.000000  0.547137 -0.873898    -0.738775    -0.298841
# SD_IP            0.547137  1.000000 -0.521435    -0.539793     0.006869
# EK_IP           -0.873898 -0.521435  1.000000     0.945729     0.414368
# Skewness_IP     -0.738775 -0.539793  0.945729     1.000000     0.412056
# Mean_DM_SNR     -0.298841  0.006869  0.414368     0.412056     1.000000
# SD_DM_SNR       -0.307016 -0.047632  0.432880     0.415140     0.796555
# EK_DM_SNR        0.234331  0.029429 -0.341209    -0.328843    -0.615971
# Skewness_DM_SNR  0.144033  0.027691 -0.214491    -0.204782    -0.354269
# Class           -0.673181 -0.363708  0.791591     0.709528     0.400876
#
#                  SD_DM_SNR  EK_DM_SNR  Skewness_DM_SNR     Class
# Mean_IP          -0.307016   0.234331         0.144033 -0.673181
# SD_IP            -0.047632   0.029429         0.027691 -0.363708
# ...

# %%
sns.countplot(x='Class', data=df)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
pd.plotting.scatter_matrix(df, alpha=0.01, figsize=(15,15))
pass

# %%
sns.pairplot(df, hue='Class')
